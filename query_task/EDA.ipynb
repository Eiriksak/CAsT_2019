# %% [markdown]
# # Exploritory Data Analysis

# %%
from collections import Counter
from string import punctuation
import spacy
import os
import json
import elasticsearch
from elasticsearch import Elasticsearch
import utils
import spacy

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
nlp = spacy.load('en_core_web_sm')

# %%
es = Elasticsearch(http_auth=(os.environ['ES_USER'], os.environ['ES_PWD']))

# %%
INDEX_NAME = 'trec2019_stem'

# %% [markdown]
# ### Load training data

# %%
path = "../treccastweb/2019/data/training/train_topics_v1.0.json"
with open(path, 'r') as f:
    train_topics = json.load(f)

# %%
path = "../baseline/train_topics_mod_nowapo.qrel"
with open(path, 'r') as f:
    qrels = []
    for line in f:
        qrels.append(line.strip())

# %% [markdown]
# ### Evaluation of retrieval

# %%
system_rankings = [2, 1, 3, 4, 5, 6, 10, 7, 9, 8]
ground_truth = {4: 3, 1: 2, 2: 1} #doc_id:relevance, scores: 0 non relevant, 1 poor, 2 good, 3 excellent

# %%
utils.ndcg(system_rankings, ground_truth, k=5)
# Out:
# 0.7991575453673245

# %% [markdown]
# ### Add query id for each turn in each topic

# %%
for topic in train_topics:
    utils.add_qid(topic)

# %% [markdown]
# ## POS tagger
# https://universaldependencies.org/u/pos/all.html

# %%
def get_pronominal(text):
    doc = nlp(text) 
    return [token.text for token in doc if token.pos_ == 'PRON']

def get_determiner(text):
    doc = nlp(text)
    return [token.text for token in doc if token.pos_ == 'DET']

def get_noun(text):
    doc = nlp(text)
    return [token.text for token in doc if token.pos_ == 'NOUN']

def get_proper_noun(text):
    doc = nlp(text)
    return [token.text for token in doc if token.pos_ == 'PROPN']
    
def get_adjective(text):
    doc = nlp(text)
    return [token.text for token in doc if token.pos_ == 'ADJ']

def get_adverb(text):
    doc = nlp(text)
    return [token.text for token in doc if token.pos_ == 'ADV']

def get_adposition(text):
    doc = nlp(text)
    return [token.text for token in doc if token.pos_ == 'ADP']

def get_verb(text):
    doc = nlp(text)
    return [token.text for token in doc if token.pos_ == 'VERB']
    

def pos_analysis(topic):
    title = topic['title']
    for i, turn in enumerate([title] + topic['turn']):
        if i == 0:
            print("## Title data ##")
            text = turn
        else:
            text = turn['raw_utterance']
        pronominals = get_pronominal(text)
        determiner = get_determiner(text)
        noun = get_noun(text)
        proper_noun = get_proper_noun(text)
        adjective = get_adjective(text)
        adverb = get_adverb(text)
        adposition = get_adposition(text)
        verb = get_verb(text)
        print(f'Original text: {text}\nPronominals: {pronominals}'
              f'\nDeterminer: {determiner}\nNoun: {noun}\n'
              f'Proper noun: {proper_noun}\nAdjective: {adjective}\n'
              f'Adverb: {adverb}\nAdposition: {adposition}\n'
              f'Verb: {verb}')
        print()

# %%
pos_analysis(train_topics[0])
pos_analysis(train_topics[3])
pos_analysis(train_topics[6])
# Out:
# ## Title data ##
# Original text: Career choice for Nursing and Physician's Assistant
# Pronominals: []
# Determiner: []
# Noun: ['Career', 'choice']
# Proper noun: ['Nursing', 'Physician', 'Assistant']
# Adjective: []
# Adverb: []
# Adposition: ['for']
# Verb: []
#
# Original text: What is a physician's assistant?
# Pronominals: ['What']
# Determiner: ['a']
# Noun: ['physician', 'assistant']
# Proper noun: []
# Adjective: []
# Adverb: []
# Adposition: []
# Verb: []
#
# Original text: What are the educational requirements required to become one?
# Pronominals: ['What']
# Determiner: ['the']
# Noun: ['requirements']
# Proper noun: []
# Adjective: ['educational']
# Adverb: []
# Adposition: []
# Verb: ['required', 'become']
#
# Original text: What does it cost?
# Pronominals: ['What', 'it']
# Determiner: []
# Noun: []
# Proper noun: []
# Adjective: []
# Adverb: []
# Adposition: []
# Verb: ['cost']
#
# Original text: What's the average starting salary in the UK?
# Pronominals: ['What']
# Determiner: ['the', 'the']
# Noun: ['starting', 'salary']
# Proper noun: ['UK']
# Adjective: ['average']
# Adverb: []
# Adposition: ['in']
# Verb: []
#
# Original text: What about in the US?
# Pronominals: ['What']
# Determiner: ['the']
# Noun: []
# Proper noun: ['US']
# Adjective: []
# Adverb: []
# Adposition: ['about', 'in']
# Verb: []
#
# Original text: What school subjects are needed to become a registered nurse?
# Pronominals: []
# Determiner: ['What', 'a']
# Noun: ['school', 'subjects', 'nurse']
# Proper noun: []
# Adjective: ['registered']
# Adverb: []
# Adposition: []
# Verb: ['needed', 'become']
#
# Original text: What is the PA average salary vs an RN?
# Pronominals: ['What']
# Determiner: ['the', 'an']
# Noun: ['PA', 'salary', 'RN']
# Proper noun: []
# Adjective: ['average']
# Adverb: []
# Adposition: ['vs']
# Verb: []
#
# Original text: What the difference between a PA and a nurse practitioner?
# Pronominals: ['What']
# Determiner: ['the', 'a', 'a']
# Noun: ['difference', 'PA', 'nurse', 'practitioner']
# Proper noun: []
# Adjective: []
# Adverb: []
# Adposition: ['between']
# Verb: []
#
# Original text: Do NPs or PAs make more?
# Pronominals: []
# Determiner: []
# Noun: ['NPs', 'PAs']
# Proper noun: []
# Adjective: ['more']
# Adverb: []
# Adposition: []
# Verb: ['make']
#
# Original text: Is a PA above a NP?
# Pronominals: []
# Determiner: ['a', 'a']
# Noun: ['PA']
# Proper noun: ['NP']
# Adjective: []
# Adverb: []
# Adposition: ['above']
# Verb: []
#
# Original text: What is the fastest way to become a NP?
# Pronominals: ['What']
# Determiner: ['the', 'a']
# Noun: ['way']
# Proper noun: ['NP']
# Adjective: ['fastest']
# Adverb: []
# Adposition: []
# Verb: ['become']
#
# Original text: How much longer does it take to become a doctor after being an NP?
# Pronominals: ['it']
# Determiner: ['a', 'an']
# Noun: ['doctor']
# Proper noun: ['NP']
# Adjective: []
# Adverb: ['How', 'much', 'longer']
# Adposition: ['after']
# Verb: ['take', 'become']
#
# ## Title data ##
# Original text: The Neolithic Revolution
# Pronominals: []
# Determiner: ['The']
# Noun: []
# Proper noun: ['Neolithic', 'Revolution']
# Adjective: []
# Adverb: []
# Adposition: []
# Verb: []
#
# Original text: What was the neolithic revolution?
# Pronominals: ['What']
# Determiner: ['the']
# Noun: ['revolution']
# Proper noun: []
# Adjective: ['neolithic']
# Adverb: []
# Adposition: []
# Verb: []
#
# Original text: When did it start and end?
# Pronominals: ['it']
# Determiner: []
# Noun: []
# Proper noun: []
# Adjective: []
# Adverb: ['When']
# Adposition: []
# Verb: ['start', 'end']
#
# Original text: Why did it start?
# Pronominals: ['it']
# Determiner: []
# Noun: []
# Proper noun: []
# Adjective: []
# Adverb: ['Why']
# Adposition: []
# Verb: ['start']
#
# Original text: What did the neolithic invent?
# Pronominals: ['What']
# Determiner: ['the']
# Noun: ['invent']
# Proper noun: []
# Adjective: ['neolithic']
# Adverb: []
# Adposition: []
# Verb: []
#
# Original text: What tools were used?
# Pronominals: []
# Determiner: ['What']
# Noun: ['tools']
# Proper noun: []
# Adjective: []
# Adverb: []
# Adposition: []
# Verb: ['used']
#
# Original text: When was it brought to the british isles?
# Pronominals: ['it']
# Determiner: ['the']
# Noun: ['isles']
# Proper noun: []
# Adjective: ['british']
# Adverb: ['When']
# Adposition: ['to']
# Verb: ['brought']
#
# Original text: Describe the period that follows it.
# Pronominals: ['it']
# Determiner: ['the', 'that']
# Noun: ['period']
# Proper noun: []
# Adjective: []
# Adverb: []
# Adposition: []
# Verb: ['Describe', 'follows']
#
# Original text: What was its significance?
# Pronominals: ['What']
# Determiner: ['its']
# Noun: ['significance']
# Proper noun: []
# Adjective: []
# Adverb: []
# Adposition: []
# Verb: []
#
# Original text: What were the houses like?
# Pronominals: ['What']
# Determiner: ['the']
# Noun: ['houses']
# Proper noun: []
# Adjective: []
# Adverb: []
# Adposition: []
# Verb: []
#
# ## Title data ##
# Original text: Macromolecules
# Pronominals: []
# Determiner: []
# Noun: ['Macromolecules']
# Proper noun: []
# Adjective: []
# Adverb: []
# Adposition: []
# Verb: []
#
# Original text: What are the different types of macromolecules?
# Pronominals: ['What']
# Determiner: ['the']
# Noun: ['types', 'macromolecules']
# Proper noun: []
# Adjective: ['different']
# Adverb: []
# Adposition: ['of']
# Verb: []
#
# Original text: Tell me about the characteristics of carbohydrates.
# Pronominals: ['me']
# Determiner: ['the']
# Noun: ['characteristics', 'carbohydrates']
# Proper noun: []
# Adjective: []
# Adverb: []
# Adposition: ['about', 'of']
# Verb: ['Tell']
#
# Original text: What are they composed of?
# Pronominals: ['What', 'they']
# Determiner: []
# Noun: []
# Proper noun: []
# Adjective: []
# Adverb: []
# Adposition: ['of']
# Verb: ['composed']
#
# Original text: What is their basic structure?
# Pronominals: ['What']
# Determiner: ['their']
# Noun: ['structure']
# Proper noun: []
# Adjective: ['basic']
# Adverb: []
# Adposition: []
# Verb: []
#
# Original text: What are the main types with examples of each?
# Pronominals: ['What']
# Determiner: ['the', 'each']
# Noun: ['types', 'examples']
# Proper noun: []
# Adjective: ['main']
# Adverb: []
# Adposition: ['with', 'of']
# Verb: []
#
# Original text: Tell me about lipids.
# Pronominals: ['me']
# Determiner: []
# Noun: ['lipids']
# Proper noun: []
# Adjective: []
# Adverb: []
# Adposition: ['about']
# Verb: ['Tell']
#
# Original text: What is their function?
# Pronominals: ['What']
# Determiner: ['their']
# Noun: ['function']
# Proper noun: []
# Adjective: []
# Adverb: []
# Adposition: []
# Verb: []
#
# Original text: What are the types of lipids?
# Pronominals: ['What']
# Determiner: ['the']
# Noun: ['types', 'lipids']
# Proper noun: []
# Adjective: []
# Adverb: []
# Adposition: ['of']
# Verb: []
#
# Original text: What is the most common?
# Pronominals: ['What']
# Determiner: ['the']
# Noun: []
# Proper noun: []
# Adjective: ['common']
# Adverb: ['most']
# Adposition: []
# Verb: []
#
# Original text: What is the difference between them and carbohydrates?
# Pronominals: ['What', 'them']
# Determiner: ['the']
# Noun: ['difference', 'carbohydrates']
# Proper noun: []
# Adjective: []
# Adverb: []
# Adposition: ['between']
# Verb: []
#
# Original text: Why are carbs better?
# Pronominals: []
# Determiner: []
# Noun: []
# Proper noun: []
# Adjective: ['carbs', 'better']
# Adverb: ['Why']
# Adposition: []
# Verb: []
